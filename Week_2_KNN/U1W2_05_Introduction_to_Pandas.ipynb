# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint
# ### Not For Grading

# %% [markdown]
# ### Learning Objective

# %% [markdown]
# At the end of this experiment, you will be able to :
#
# * Use Pandas Library

# %% [markdown]
# ### Dataset

# %% [markdown]
# #### Description

# %% [markdown]
# The dataset choosen for this exercise is an employee dataset. The dataset contains the following information regarding a particular employee:
#
# * Emp ID
# * Name Prefix
# * First Name
# * Middle Initial
# * Last Name
# * Gender
# * E Mail
# * Father's Name
# * Mother's Name
# * Mother's Maiden Name
# * Date of Birth
# * Time of Birth
# * Age in Yrs
# *  Weight in Kgs
# * Date of Joining
# * Quarter of Joining
# * Half of Joining
# * Year of Joining
# * Month of Joining
# * Month Name of Joining
# * Short Month
# * Day of Joining
# * DOW of Joining
# * Short DOW
# * Age in Company (Years)
# * Salary
# * Last % Hike
# * SSN
# * Phone No
# * Place Name
# * CountyCity,
# * State
# * Zip
# * Region
# * User Name
# * Password

# %% [markdown]
# ## Setup Steps

# %%
#@title Please enter your registration id to start: { run: "auto", display-mode: "form" }
Id = "2512297" #@param {type:"string"}

# %%
#@title Please enter your password (normally your phone number) to continue: { run: "auto", display-mode: "form" }
password = "7010198219" #@param {type:"string"}

# %% [markdown]
# ##### After creating a copy of the notebook, follow the instructions below based on your batch:
#
# * PG Batch: Run the below cell as it is.
#
# * AC (Advanced) Batch: Follow the steps below to avoid execution errors.
#
# 1. Click on “Show Code” under the cell labeled:
#     “Run this cell to complete the setup for this Notebook.”
#
# 2. Refer to the attached snippet and locate the red-highlighted section.
#
# 4. Add the following code snippet under the “Show Code” section, ensuring that the correct cohort ID is used in place of the example shown below:
#
#            "batch": "IIITH-AC-AIML-27"
#
# ![Colab Error.png](data:image/png;base64,...)

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()

notebook= "U1W2_05_Introduction_to_Pandas" #name of the notebook
Answer = "Ungraded"
def setup():
#  ipython.magic("sx pip3 install torch")
    from IPython.display import HTML, display
    ipython.magic("sx wget https://cdn.talentsprint.com/aiml/Experiment_related_data/Employee.csv")
    display(HTML('<script src="https://dashboard.talentsprint.com/submissions/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():

    ipython.magic("notebook -e "+ notebook + ".ipynb")

    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword(), "batch" : "IIITH-AC-AIML-27"}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:
        print(r["err"])
        return None
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getComplexity() and getAdditional() and getConcepts() and getComments():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional,
              "concepts" : Concepts, "record_id" : submission_id,
              "id" : Id, "file_hash" : file_hash,
              "feedback_experiments_input" : Comments, "notebook" : notebook, "batch" : "IIITH-AC-AIML-27"}

      r = requests.post(url, data = data)
      r = json.loads(r.text)
      if "err" in r:
        print(r["err"])
        return None
      else:
        print("Your submission is successful.")
        print("Ref Id:", submission_id)
        print("Date of submission: ", r["date"])
        print("Time of submission: ", r["time"])
        print("View your submissions: https://learn-iiith.talentsprint.com/notebook_submissions")
        # print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
      return submission_id
    else: submission_id


def getAdditional():
  try:
    if not Additional:
      raise NameError
    else:
      return Additional
  except NameError:
    print ("Please answer Additional Question")
    return None
def getComments():
  try:
    if not Comments:
      raise NameError
    else:
      return Comments
  except NameError:
    print ("Please answer Comments Question")
    return None

def getComplexity():
  try:
    if not Complexity:
      raise NameError
    else:
      return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None

def getConcepts():
  try:
    if not Concepts:
      raise NameError
    else:
      return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None

def getId():
  try:
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()

else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/submissions/record_ip.html?traineeId=2512297&recordId=2311"></script>
# Setup completed successfully

# %% [markdown]
# ## 1. Load the dataset with index as 'Emp Id'

# %%
import pandas as pd

# %%
dataset = pd.read_csv("/content/Employee.csv")
# YOUR CODE HERE

# %% [markdown]
# ### 2. Display the first 5 entries of the dataset

# %%
# YOUR CODE HERE
dataset.head()
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
# 1  940761         Ms.     Brenda              S  Robinson      F
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
#
#                          E Mail     Father's Name       Mother's Name  \
# 0       lois.walker@hotmail.com     Donald Walker        Helen Walker
# 1     brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 2        joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
# 3         diane.evans@yahoo.com       Jason Evans      Michelle Evans
# 4  benjamin.russell@charter.net   Gregory Russell   Elizabeth Russell
#
#   Mother's Maiden Name  ...          SSN    Phone No.     Place Name  \
# 0                Lewis  ...  467-99-4677  303-572-8492        Denver
# ...

# %% [markdown]
# ### 3. How many  records are there in the dataset?

# %%
print(dataset.shape[0])
# Out:
# 100

# %% [markdown]
# ### 4. How many columns are there in the dataset?

# %%
# YOUR CODE HERE
print(dataset.shape[1])
# Out:
# 37

# %% [markdown]
# ### 5. Print the name of all the columns in the dataset

# %%
# YOUR CODE HERE
dataset.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %% [markdown]
# ### 6. What is  the name of the 20th column ?

# %%
# YOUR CODE HERE
import numpy as np

# %%
col_names=np.array(dataset.columns)
col_names[19]
# Out:
# 'Month Name of Joining'

# %% [markdown]
# ### 7. What is  the datatype of each column in the dataset?

# %%
# YOUR CODE HERE
dataset.dtypes
# Out:
# Emp ID                      int64
# Name Prefix                object
# First Name                 object
# Middle Initial             object
# Last Name                  object
# Gender                     object
# E Mail                     object
# Father's Name              object
# Mother's Name              object
# Mother's Maiden Name       object
# Date of Birth              object
# Time of Birth              object
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Date of Joining            object
# Quarter of Joining         object
# Half of Joining            object
# Year of Joining             int64
# Month of Joining            int64
# Month Name of Joining      object
# Short Month                object
# Day of Joining              int64
# DOW of Joining             object
# Short DOW                  object
# Age in Company (Years)    float64
# Salary                      int64
# Last % Hike                object
# ...

# %% [markdown]
# ### 8. Display the columns from 5 to 9 and rows 1 to 3 of the dataset

# %%
# YOUR CODE HERE
dataset.iloc[:3,5:10]
# Out:
#   Gender                     E Mail     Father's Name       Mother's Name  \
# 0      F    lois.walker@hotmail.com     Donald Walker        Helen Walker
# 1      F  brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 2      M     joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
#
#   Mother's Maiden Name
# 0                Lewis
# 1                Perry
# 2               Taylor

# %% [markdown]
# ### 9. Display all the rows after 50th row of the dataset

# %%
dataset[51::]
# Out:
#     Emp ID Name Prefix   First Name Middle Initial   Last Name Gender  \
# 51  447813        Mrs.          Ann              Q     Coleman      F
# 52  525955        Drs.         Judy              C    Gonzales      F
# 53  818384         Mr.        Peter              X  Washington      M
# 54  971640       Prof.     Clarence              A        Ross      M
# 55  253573         Ms.       Sharon              E       Lopez      F
# 56  904898        Drs.          Ann              Q      Cooper      F
# 57  515103         Ms.         Anne              A       Perez      F
# 58  491943        Mrs.        Nancy              P      Howard      F
# 59  750173         Mr.      Antonio              R     Roberts      M
# 60  687017         Ms.      Frances              P      Watson      F
# 61  241882         Ms.        Debra              G        Wood      F
# 62  758872         Mr.        Henry              Y     Jenkins      M
# ...

# %%
# YOUR CODE HERE
dataset.iloc[51:]
# Out:
#     Emp ID Name Prefix   First Name Middle Initial   Last Name Gender  \
# 51  447813        Mrs.          Ann              Q     Coleman      F
# 52  525955        Drs.         Judy              C    Gonzales      F
# 53  818384         Mr.        Peter              X  Washington      M
# 54  971640       Prof.     Clarence              A        Ross      M
# 55  253573         Ms.       Sharon              E       Lopez      F
# 56  904898        Drs.          Ann              Q      Cooper      F
# 57  515103         Ms.         Anne              A       Perez      F
# 58  491943        Mrs.        Nancy              P      Howard      F
# 59  750173         Mr.      Antonio              R     Roberts      M
# 60  687017         Ms.      Frances              P      Watson      F
# 61  241882         Ms.        Debra              G        Wood      F
# 62  758872         Mr.        Henry              Y     Jenkins      M
# ...

# %% [markdown]
# ### 10. Display the columns from 10 to 12 for first 50 rows of the dataset

# %%
# YOUR CODE HERE
dataset.iloc[:50,10:13]
# Out:
#    Date of Birth Time of Birth  Age in Yrs.
# 0      3/29/1981   02:31:49 AM        36.36
# 1      7/31/1970   12:13:27 PM        47.02
# 2      6/16/1963   10:45:36 AM        54.15
# 3      12/4/1977   02:18:45 AM        39.67
# 4      4/17/1977   05:41:11 PM        40.31
# 5      9/27/1982   01:12:41 PM        34.86
# 6      6/13/1995   08:56:32 PM        22.14
# 7      6/30/1958   10:39:33 AM        59.12
# 8       6/9/1959   04:38:47 PM        58.18
# 9     11/13/1987   03:59:26 AM        29.73
# 10      2/5/1975   02:15:50 AM        42.50
# 11     5/19/1995   04:33:57 PM        22.21
# 12     2/24/1972   06:04:57 PM        45.45
# 13     6/26/1996   12:23:21 AM        21.10
# 14     2/23/1958   06:59:29 PM        59.47
# 15     8/22/1966   08:11:15 PM        50.97
# 16     5/18/1970   03:47:46 AM        47.23
# 17     12/5/1992   09:20:52 AM        24.66
# 18     7/15/1959   09:24:39 PM        58.08
# 19     10/4/1967   08:28:14 PM        49.85
# ...

# %% [markdown]
# ### 11. Display the information of the employees who have  joined in Quarter 1 and 4.

# %%
# YOUR CODE HERE
dataset_employess=dataset[dataset['Quarter of Joining'].isin(['Q1','Q4'])]
dataset_employess
# Out:
#     Emp ID Name Prefix   First Name Middle Initial   Last Name Gender  \
# 0   677509        Drs.         Lois              H      Walker      F
# 7   380086        Mrs.        Carol              V      Murphy      F
# 9   162402        Hon.        Diana              T    Peterson      F
# 11  153989       Prof.         Jack              C   Alexander      M
# 12  386158        Mrs.      Melissa              Q        King      F
# 14  441771        Mrs.       Cheryl              O       Scott      F
# 17  214352         Ms.      Theresa              G         Lee      F
# 18  890290        Hon.        Julia              S       Scott      F
# 21  969580       Prof.      Matthew              L      Turner      M
# 22  426038        Hon.         Joan              C     Stewart      F
# 25  477253        Mrs.         Anne              L     Russell      F
# 26  263480        Hon.       Daniel              K      Cooper      M
# ...

# %% [markdown]
# ### 12. How many people are from the southern region joined on Monday?

# %%
dataset['Date of Joining']
# Out:
# 0     11/24/2003
# 1      7/27/2008
# 2       8/3/2016
# 3      4/16/1999
# 4      7/25/2013
#          ...
# 95      7/9/2016
# 96     8/23/2011
# 97     1/23/1989
# 98      8/3/2010
# 99     4/25/2015
# Name: Date of Joining, Length: 100, dtype: object

# %%
dataset['Date of Joining'] = pd.to_datetime(dataset['Date of Joining'])

# %%
dataset['Day of Week'] = dataset['Date of Joining'].dt.day_name()

# %%
display(dataset[['Date of Joining', 'Day of Week']].head())
# Out:
#   Date of Joining Day of Week
# 0      2003-11-24      Monday
# 1      2008-07-27      Sunday
# 2      2016-08-03   Wednesday
# 3      1999-04-16      Friday
# 4      2013-07-25    Thursday

# %%
# YOUR CODE HERE
#Region,Day of Joining
#len(dataset[(dataset['Region'] == 'South') & (dataset['DOW of Joining'] == 'Monday')])
len(dataset[(dataset['Region']=='South') & (dataset['Day of Week']=='Monday')])
# Out:
# 9

# %% [markdown]
# ### 13. Display the information of the employees who have more than 13 years experience in the company

# %%
# YOUR CODE HERE
dataset[dataset['Age in Company (Years)']>13]
# Out:
#     Emp ID Name Prefix   First Name Middle Initial  Last Name Gender  \
# 0   677509        Drs.         Lois              H     Walker      F
# 3   408351        Drs.        Diane              I      Evans      F
# 7   380086        Mrs.        Carol              V     Murphy      F
# 8   477616        Hon.      Frances              B      Young      F
# 14  441771        Mrs.       Cheryl              O      Scott      F
# 15  528509        Hon.        Paula              G       Diaz      F
# 16  912990         Mr.       Joshua              T    Stewart      M
# 19  622406         Mr.       Thomas              Q      Lewis      M
# 24  560455         Ms.      Carolyn              V      Hayes      F
# 28  474599        Drs.        Maria              W     Walker      F
# 29  335732         Ms.       Brenda              M     Butler      F
# 31  893212         Ms.          Amy              B     Howard      F
# 35  333476        Hon.         Mary              P     Wilson      F
# ...

# %% [markdown]
# ### 14. There is a lot of redundant data. For example, the information in the below columns is also available in the *Date of Joining* column.
#
#   1.   month of Joining
#   2.   year of Joining
#   3.   Day of Joining
#
# There could be other such columns containing redundant data. Please identify such columns and take appropriate action.
#
#
# You can refer to the below link :
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html

# %%
# YOUR CODE HERE
dataset[['Age in Yrs.','Quarter of Joining','Half of Joining', 'Year of Joining', 'Month of Joining',
       'Month Name of Joining', 'Short Month', 'Day of Joining',
       'DOW of Joining', 'Short DOW','Age in Company (Years)','Day of Week']].head()
# Out:
#    Age in Yrs. Quarter of Joining Half of Joining  Year of Joining  \
# 0        36.36                 Q4              H2             2003
# 1        47.02                 Q3              H2             2008
# 2        54.15                 Q3              H2             2016
# 3        39.67                 Q2              H1             1999
# 4        40.31                 Q3              H2             2013
#
#    Month of Joining Month Name of Joining Short Month  Day of Joining  \
# 0                11              November         Nov              24
# 1                 7                  July         Jul              27
# 2                 8                August         Aug               3
# 3                 4                 April         Apr              16
# 4                 7                  July         Jul              25
#
#   DOW of Joining Short DOW  Age in Company (Years) Day of Week
# 0         Monday       Mon                   13.68      Monday
# ...

# %%
dataset_copy=dataset.copy()

# %%
dataset_copy.shape
# Out:
# (100, 38)

# %%
datset_nonredundant=dataset_copy.drop(columns=['Age in Yrs.','Quarter of Joining','Half of Joining', 'Year of Joining', 'Month of Joining',
       'Month Name of Joining', 'Short Month', 'Day of Joining',
       'DOW of Joining', 'Short DOW','Age in Company (Years)','Day of Week'],axis=1)

# %%
datset_nonredundant.shape
# Out:
# (100, 26)

# %% [markdown]
# ### 15. Remove "%" sign from the "Last % Hike" column values of the dataset
#
# you can refer the below link :
#
# https://stackoverflow.com/questions/52850192/python-extract-last-letter-of-a-string-from-a-pandas-column

# %%
# YOUR CODE HERE
datset_nonredundant['Last % Hike']=datset_nonredundant['Last % Hike'].str.replace("%","")

# %%
datset_nonredundant=datset_nonredundant.rename(columns={'Last % Hike':'Last_Hike'})
datset_nonredundant.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth',
#        'Weight in Kgs.', 'Date of Joining', 'Salary', 'Last_Hike', 'SSN',
#        'Phone No. ', 'Place Name', 'County', 'City', 'State', 'Zip', 'Region',
#        'User Name', 'Password'],
#       dtype='object')

# %% [markdown]
# ### 16. How many Female employees got hike more than 20% ?

# %%
datset_nonredundant[(datset_nonredundant['Last_Hike'].astype(int)>20) & (datset_nonredundant['Gender']=='F')]
# Out:
#     Emp ID Name Prefix First Name Middle Initial   Last Name Gender  \
# 0   677509        Drs.       Lois              H      Walker      F
# 1   940761         Ms.     Brenda              S    Robinson      F
# 8   477616        Hon.    Frances              B       Young      F
# 20  979607         Ms.      Carol              J     Edwards      F
# 25  477253        Mrs.       Anne              L     Russell      F
# 28  474599        Drs.      Maria              W      Walker      F
# 29  335732         Ms.     Brenda              M      Butler      F
# 30  329752        Hon.    Lillian              X       Brown      F
# 31  893212         Ms.        Amy              B      Howard      F
# 41  227922        Hon.     Amanda              M      Hughes      F
# 44  407061         Ms.  Elizabeth              Q     Jackson      F
# 47  524896         Ms.       Judy              Y   Hernandez      F
# 55  253573         Ms.     Sharon              E       Lopez      F
# ...

# %% [markdown]
# ### Summary

# %% [markdown]
# To know more about Pandas, you can refer below link :
#
# https://www.machinelearningplus.com/python/101-pandas-exercises-python/

# %% [markdown]
# ### Please answer the questions below to complete the experiment:

# %%
#@title How was the experiment? { run: "auto", form-width: "500px", display-mode: "form" }
Complexity = "Good and Challenging for me" #@param ["","Too Simple, I am wasting time", "Good, But Not Challenging for me", "Good and Challenging for me", "Was Tough, but I did it", "Too Difficult for me"]

# %%
#@title If it was too easy, what more would you have liked to be added? If it was very difficult, what would you have liked to have been removed? { run: "auto", display-mode: "form" }
Additional = "good for practise" #@param {type:"string"}

# %%
#@title Can you identify the concepts from the lecture which this experiment covered? { run: "auto", vertical-output: true, display-mode: "form" }
Concepts = "Yes" #@param ["","Yes", "No"]

# %%
#@title  Experiment walkthrough video? { run: "auto", vertical-output: true, display-mode: "form" }
Walkthrough = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title  Text and image description/explanation and code comments within the experiment: { run: "auto", vertical-output: true, display-mode: "form" }
Comments = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Mentor Support: { run: "auto", vertical-output: true, display-mode: "form" }
Mentor_support = "" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Run this cell to submit your notebook for Ungrading { vertical-output: true }
try:
  if submission_id:
      return_id = submit_notebook()
      if return_id : submission_id = return_id
  else:
      print("Please complete the setup first.")
except NameError:
  print ("Please complete the setup first.")
# Out:
# Your submission is successful.
# Ref Id: 2311
# Date of submission:  16 May 2026
# Time of submission:  19:37:11
# View your submissions: https://learn-iiith.talentsprint.com/notebook_submissions
